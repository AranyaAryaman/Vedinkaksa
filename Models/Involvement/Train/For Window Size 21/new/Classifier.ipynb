# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import numpy as np

def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)


scores_logistic = []
scores_svm = []
scores_rf = []
x=1
for x in range(1,31):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_svm.append(get_score(SVC(gamma='auto'), X_train, X_test, y_train, y_test))
    print('Iteration '+str(x)+' completed')

print(scores_svm)
print(np.mean(scores_svm))
print(np.max(scores_svm))
print(np.min(scores_svm))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# [0.3703339882121807, 0.8289473684210527, 0.8033240997229917, 0.7043664996420902, 0.6943231441048034, 0.8133174791914387, 0.23225152129817445, 0.7439664218258132, 0.9211956521739131, 0.681618722574354, 0.7111209570225964, 0.9126378286683631, 0.5788271134805788, 0.5460122699386503, 0.2987582176771366, 0.7833474936278675, 0.8, 0.8102477477477478, 0.9124860646599777, 0.5867768595041323, 0.716624685138539, 0.6493617021276595, 0.8420062695924765, 0.7641764176417641, 0.6260869565217392, 0.6343283582089553, 0.684107259646828, 0.7436293436293436, 0.912, 0.5167322834645669]
# 0.6940970908488578
# 0.9211956521739131
# 0.23225152129817445

# %%
for x in range(1,31):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_logistic.append(get_score(LogisticRegression(solver='liblinear',multi_class='ovr'), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_logistic)
print(np.mean(scores_logistic))
print(np.max(scores_logistic))
print(np.min(scores_logistic))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# [0.49656188605108054, 0.6803405572755418, 0.5581717451523546, 0.7208303507516106, 0.6768558951965066, 0.7728894173602854, 0.42190669371196754, 0.8121720881427072, 0.7567934782608695, 0.8225255972696246, 0.6792202038103677, 0.9372349448685326, 0.7875095201827875, 0.47955010224948874, 0.25493060628195763, 0.6380628717077316, 0.9325183374083129, 0.9470720720720721, 0.8974358974358975, 0.6132231404958678, 0.7141057934508817, 0.40425531914893614, 0.8169278996865204, 0.8217821782178217, 0.8869565217391304, 0.9797441364605544, 0.5467625899280576, 1.0, 0.884, 0.6683070866141733]
# 0.7202882310310545
# 1.0
# 0.25493060628195763

# %%
for x in range(1,31):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_rf)
print(np.mean(scores_rf))
print(np.max(scores_rf))
print(np.min(scores_rf))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# [0.56286836935167, 0.9365325077399381, 0.6329639889196675, 0.768790264853257, 0.7978789769182782, 0.772294887039239, 0.48782961460446245, 0.8058761804826863, 0.7615489130434783, 0.7415894685519259, 0.718653079308817, 0.9007633587786259, 0.5734958111195735, 0.523517382413088, 0.33820306793279764, 0.7774001699235344, 0.784841075794621, 0.8614864864864865, 0.8924191750278707, 0.6132231404958678, 0.7336272040302267, 0.6740425531914893, 0.8344827586206897, 0.7776777677767777, 0.7905138339920948, 0.685501066098081, 0.7436232831916285, 0.8471042471042471, 0.916, 0.390748031496063]
# 0.7215165554762394
# 0.9365325077399381
# 0.33820306793279764
