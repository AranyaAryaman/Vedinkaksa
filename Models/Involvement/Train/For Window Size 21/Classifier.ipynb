# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import numpy as np

def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)


scores_logistic = []
scores_svm = []
scores_rf = []
x=1
for x in range(1,35):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_svm.append(get_score(SVC(gamma='auto'), X_train, X_test, y_train, y_test))
    print('Iteration '+str(x)+' completed')

print(scores_svm)
print(np.mean(scores_svm))
print(np.max(scores_svm))
print(np.min(scores_svm))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.19204322200392926, 0.8204334365325078, 0.7867036011080333, 0.7029348604151754, 0.7217716781035558, 0.8097502972651606, 0.5557809330628803, 0.47285886610373945, 0.7502623294858342, 0.9089673913043478, 0.6567528035104827, 0.7155516171909615, 0.926208651399491, 0.5864432597105864, 0.5460122699386503, 0.7144522144522144, 0.3389335281227173, 0.7807986406117248, 0.3861111111111111, 0.823960880195599, 0.7725225225225225, 0.9085841694537347, 0.509090909090909, 0.7304785894206549, 0.6519148936170213, 0.845141065830721, 0.8208820882088209, 0.6407142857142857, 0.4632411067193676, 0.6268656716417911, 0.6801831262262917, 0.752895752895753, 0.903, 0.49311023622047245]
# 0.676334000270325
# 0.926208651399491
# 0.19204322200392926

# %%
for x in range(1,35):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_logistic.append(get_score(LogisticRegression(solver='liblinear',multi_class='ovr'), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_logistic)
print(np.mean(scores_logistic))
print(np.max(scores_logistic))
print(np.min(scores_logistic))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.7224950884086444, 0.6602167182662538, 0.5581717451523546, 0.6048675733715104, 0.6119775421085465, 0.7520808561236623, 0.42190669371196754, 0.22677925211097708, 0.9989506820566632, 0.6997282608695652, 0.8352023403217943, 0.6756756756756757, 0.8787107718405428, 0.7486671744097486, 0.47955010224948874, 0.5582750582750583, 0.2731921110299489, 0.6125743415463042, 0.4981481481481482, 0.887041564792176, 0.9887387387387387, 0.8651059085841695, 0.6132231404958678, 0.7021410579345088, 0.40425531914893614, 0.729153605015674, 0.7443744374437443, 0.74, 0.9407114624505929, 0.9307036247334755, 0.5467625899280576, 0.9868725868725868, 0.849, 0.8346456692913385]
# 0.6935264659149035
# 0.9989506820566632
# 0.22677925211097708

# %%
for x in range(1,35):
    data_train  =  pd.read_csv('Train_21_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_21_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_rf)
print(np.mean(scores_rf))
print(np.max(scores_rf))
print(np.min(scores_rf))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.4577603143418468, 0.903250773993808, 0.6343490304709142, 0.7186828919112384, 0.7804117280099813, 0.7699167657550535, 0.6673427991886409, 0.5705669481302774, 0.8079748163693599, 0.735733695652174, 0.6235982447586543, 0.6982720425343376, 0.8787107718405428, 0.5734958111195735, 0.49795501022494887, 0.6911421911421911, 0.26515704894083275, 0.7723024638912489, 0.5, 0.7970660146699267, 0.8530405405405406, 0.9052396878483835, 0.5231404958677686, 0.7367758186397985, 0.6289361702127659, 0.8344827586206897, 0.7767776777677767, 0.6771428571428572, 0.5201581027667984, 0.6791044776119403, 0.7305428384565075, 0.8432432432432433, 0.906, 0.41732283464566927]
# 0.6875175548914791
# 0.906
# 0.26515704894083275
