# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import numpy as np

def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)


scores_logistic = []
scores_svm = []
scores_rf = []
x=1
for x in range(1,35):
    data_train  =  pd.read_csv('Train_60_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_60_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_svm.append(get_score(SVC(gamma='auto'), X_train, X_test, y_train, y_test))
    print('Iteration '+str(x)+' completed')

print(scores_svm)
print(np.mean(scores_svm))
print(np.max(scores_svm))
print(np.min(scores_svm))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.20275791624106232, 0.8014827018121911, 0.6770186335403726, 0.5572403335860501, 0.700983606557377, 0.7687032418952618, 0.4988986784140969, 0.5411392405063291, 0.7748571428571429, 0.7890961262553802, 0.685250886974151, 0.6938962826984856, 0.9028156221616712, 0.5441295546558704, 0.6422222222222222, 0.6038461538461538, 0.7405112316034083, 0.7024567788898999, 0.3273453093812375, 0.8307066598881545, 0.7603062426383981, 0.8566433566433567, 0.35954063604240283, 0.6867549668874172, 0.6289881494986327, 0.8417930125247198, 0.7831558567279767, 0.6770045385779122, 0.510530749789385, 0.622093023255814, 0.729841488628532, 0.5201314708299096, 0.7776572668112798, 0.603411513859275]
# 0.6571532528441626
# 0.9028156221616712
# 0.20275791624106232

# %%
for x in range(1,35):
    data_train  =  pd.read_csv('Train_60_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_60_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_logistic.append(get_score(LogisticRegression(solver='liblinear',multi_class='ovr'), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_logistic)
print(np.mean(scores_logistic))
print(np.max(scores_logistic))
print(np.min(scores_logistic))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.7129724208375894, 0.6210873146622735, 0.5652173913043478, 0.6087945413191812, 0.6072131147540983, 0.7549875311720698, 0.41519823788546256, 0.21329113924050633, 1.0, 0.7109038737446198, 0.8423720223010643, 0.6691142726021111, 0.8937329700272479, 0.7441295546558705, 0.4777777777777778, 0.5371794871794872, 0.24012393493415957, 0.5777979981801638, 0.49800399201596807, 0.8937468225724453, 0.9941107184923439, 0.8782051282051282, 0.6210247349823321, 0.7119205298013245, 0.3974475843208751, 0.7350032959789057, 0.782187802516941, 0.7344931921331316, 0.9553496208930076, 0.9627906976744186, 0.549276361130255, 1.0, 0.8286334056399133, 0.8390191897654584]
# 0.6933266664323671
# 1.0
# 0.21329113924050633

# %%
for x in range(1,35):
    data_train  =  pd.read_csv('Train_60_'+str(x)+'.csv')
    data_test  =  pd.read_csv('Test_60_'+str(x)+'.csv')
    X_train, X_test, y_train, y_test = data_train[['mem','temp','acc','rot']], data_test[['mem','temp','acc','rot']], \
                                        data_train['class'],data_test['class']
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), X_train, X_test, y_train, y_test))  
    print('Iteration '+str(x)+' completed')

print(scores_rf)
print(np.mean(scores_rf))
print(np.max(scores_rf))
print(np.min(scores_rf))
# Out:
# Iteration 1 completed
# Iteration 2 completed
# Iteration 3 completed
# Iteration 4 completed
# Iteration 5 completed
# Iteration 6 completed
# Iteration 7 completed
# Iteration 8 completed
# Iteration 9 completed
# Iteration 10 completed
# Iteration 11 completed
# Iteration 12 completed
# Iteration 13 completed
# Iteration 14 completed
# Iteration 15 completed
# Iteration 16 completed
# Iteration 17 completed
# Iteration 18 completed
# Iteration 19 completed
# Iteration 20 completed
# Iteration 21 completed
# Iteration 22 completed
# Iteration 23 completed
# Iteration 24 completed
# Iteration 25 completed
# Iteration 26 completed
# Iteration 27 completed
# Iteration 28 completed
# Iteration 29 completed
# Iteration 30 completed
# Iteration 31 completed
# Iteration 32 completed
# Iteration 33 completed
# Iteration 34 completed
# [0.21756894790602654, 0.8904448105436573, 0.5559006211180124, 0.6808188021228203, 0.8, 0.7942643391521197, 0.5099118942731278, 0.5386075949367088, 0.8148571428571428, 0.9368723098995696, 0.633046122655854, 0.6961909132629647, 0.9291553133514986, 0.5927125506072874, 0.47888888888888886, 0.8025641025641026, 0.3268783888458559, 0.7707006369426752, 0.49800399201596807, 0.8474834773767158, 0.8610129564193169, 0.8962703962703963, 0.5477031802120141, 0.7251655629139073, 0.6663628076572471, 0.8068556361239289, 0.8025169409486931, 0.6369137670196672, 0.5577085088458298, 0.6267441860465116, 0.7491385251550655, 0.7674609695973705, 0.8709327548806941, 0.31556503198294245]
# 0.680741825688076
# 0.9368723098995696
# 0.21756894790602654
